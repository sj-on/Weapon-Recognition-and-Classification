# %% [markdown]
# ## Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## GPU Specifications Check

# %%
# !nvidia-smi
# Out:
# Wed Jul  8 15:14:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Navigating to "My Drive".
# More Navigations Ahead.

# %%
# %cd 'My Drive'
# Out:
# /content/gdrive/My Drive

# %%
# !ls
# Out:
# '01 - Migraine.mp3'		   Images_Downloader44.jpg
# 'Class 10 Chemistry Notes'	   Images_Downloader45.jpg
#  Classroom			   Images_Downloader46.jpg
# 'Colab Notebooks'		   Images_Downloader47.jpg
# 'EPFEK prefinal copy draft.docx'   Images_Downloader48.jpg
# 'Getting started.pdf'		   Images_Downloader49.jpg
#  Handgun-SemiAutomaticPistol	   Images_Downloader4.jpg
#  Images_Downloader		   Images_Downloader50.jpg
#  Images_Downloader10.jpg	   Images_Downloader51.jpg
#  Images_Downloader11.jpg	   Images_Downloader52.jpg
#  Images_Downloader12.jpg	   Images_Downloader53.jpg
#  Images_Downloader13.jpg	   Images_Downloader54.jpg
#  Images_Downloader14.jpg	   Images_Downloader55.jpg
#  Images_Downloader15.jpg	   Images_Downloader56.jpg
#  Images_Downloader16.jpg	   Images_Downloader57.jpg
#  Images_Downloader17.jpg	   Images_Downloader58.jpg
#  Images_Downloader18.jpg	   Images_Downloader59.jpg
#  Images_Downloader19.jpg	   Images_Downloader5.jpg
# ...

# %%
# %cd Labelled-Images/
# Out:
# /content/gdrive/My Drive/Labelled-Images

# %%
# %cd SemiAutomaticPistol/
# Out:
# /content/gdrive/My Drive/Labelled-Images/SemiAutomaticPistol

# %%
# !ls
# Out:
# 10.jpg	19.jpg	27.jpg	35.jpg	43.jpg	51.jpg	5.jpg	68.jpg	76.jpg
# 10.txt	19.txt	27.txt	35.txt	43.txt	51.txt	5.txt	68.txt	76.txt
# 11.jpg	1.jpg	28.jpg	36.jpg	44.jpg	52.jpg	60.jpg	69.jpg	77.jpg
# 11.txt	1.txt	28.txt	36.txt	44.txt	52.txt	60.txt	69.txt	77.txt
# 12.jpg	20.jpg	29.jpg	37.jpg	45.jpg	53.jpg	61.jpg	6.jpg	78.jpg
# 12.txt	20.txt	29.txt	37.txt	45.txt	53.txt	61.txt	6.txt	78.txt
# 13.jpg	21.jpg	2.jpg	38.jpg	46.jpg	54.jpg	62.jpg	70.jpg	79.jpg
# 13.txt	21.txt	2.txt	38.txt	46.txt	54.txt	62.txt	70.txt	79.txt
# 14.jpg	22.jpg	30.jpg	39.jpg	47.jpg	55.jpg	63.jpg	71.jpg	7.jpg
# 14.txt	22.txt	30.txt	39.txt	47.txt	55.txt	63.txt	71.txt	7.txt
# 15.jpg	23.jpg	31.jpg	3.jpg	48.jpg	56.jpg	64.jpg	72.jpg	80.jpg
# 15.txt	23.txt	31.txt	3.txt	48.txt	56.txt	64.txt	72.txt	80.txt
# 16.jpg	24.jpg	32.jpg	40.jpg	49.jpg	57.jpg	65.jpg	73.jpg	8.jpg
# 16.txt	24.txt	32.txt	40.txt	49.txt	57.txt	65.txt	73.txt	8.txt
# 17.jpg	25.jpg	33.jpg	41.jpg	4.jpg	58.jpg	66.jpg	74.jpg	9.jpg
# ...

# %% [markdown]
# ### Copy Command

# %%
# !cp -R * "/content/gdrive/My Drive/yolov3/images"

# %% [markdown]
# ## Cloning darknet framework

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/gdrive/My Drive/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# ## Copying Configuration Files for Training

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %%
# !echo "Semi_Automatic_Pistol" > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data
# !mkdir data/obj

# %% [markdown]
# ## Downloading darknet CNN

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2020-07-08 15:47:25--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   314KB/s    in 9m 24s
#
# 2020-07-08 15:56:52 (281 KB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls
# Out:
# 3rdparty   CMakeLists.txt	   image_yolov2.sh	  obj
# backup	   darknet		   image_yolov3.sh	  README.md
# build	   darknet53.conv.74	   include		  results
# build.ps1  DarknetConfig.cmake.in  json_mjpeg_streams.sh  scripts
# build.sh   darknet.py		   LICENSE		  src
# cfg	   darknet_video.py	   Makefile		  video_v2.sh
# cmake	   data			   net_cam_v3.sh	  video_yolov3.sh

# %%
# %cd darknet
# Out:
# /content/gdrive/My Drive/darknet

# %%
# !ls
# Out:
# '01 - Migraine.mp3'		   Images_Downloader44.jpg
# 'Class 10 Chemistry Notes'	   Images_Downloader45.jpg
#  Classroom			   Images_Downloader46.jpg
# 'Colab Notebooks'		   Images_Downloader47.jpg
#  darknet			   Images_Downloader48.jpg
# 'EPFEK prefinal copy draft.docx'   Images_Downloader49.jpg
# 'Getting started.pdf'		   Images_Downloader4.jpg
#  Handgun-SemiAutomaticPistol	   Images_Downloader50.jpg
#  Images_Downloader		   Images_Downloader51.jpg
#  Images_Downloader10.jpg	   Images_Downloader52.jpg
#  Images_Downloader11.jpg	   Images_Downloader53.jpg
#  Images_Downloader12.jpg	   Images_Downloader54.jpg
#  Images_Downloader13.jpg	   Images_Downloader55.jpg
#  Images_Downloader14.jpg	   Images_Downloader56.jpg
#  Images_Downloader15.jpg	   Images_Downloader57.jpg
#  Images_Downloader16.jpg	   Images_Downloader58.jpg
#  Images_Downloader17.jpg	   Images_Downloader59.jpg
#  Images_Downloader18.jpg	   Images_Downloader5.jpg
#  Images_Downloader19.jpg	   Images_Downloader60.jpg
# ...

# %%
# !ls
# Out:
# 3rdparty   CMakeLists.txt	   image_yolov2.sh	  obj
# backup	   darknet		   image_yolov3.sh	  README.md
# build	   darknet53.conv.74	   include		  results
# build.ps1  DarknetConfig.cmake.in  json_mjpeg_streams.sh  scripts
# build.sh   darknet.py		   LICENSE		  src
# cfg	   darknet_video.py	   Makefile		  video_v2.sh
# cmake	   data			   net_cam_v3.sh	  video_yolov3.sh

# %%
! ls data/obj

# %%
# %cd "/content/gdrive/My Drive/yolov3/images/"
# Out:
# /content/gdrive/My Drive/yolov3/images

# %%
# !mv * "/content/gdrive/My Drive/darknet/data/obj"

# %%
# %cd "/content/gdrive/My Drive/darknet/"
# Out:
# /content/gdrive/My Drive/darknet

# %%
# !ls data/obj
# Out:
# 10.jpg	19.jpg	27.jpg	35.jpg	43.jpg	51.jpg	5.jpg	68.jpg	76.jpg
# 10.txt	19.txt	27.txt	35.txt	43.txt	51.txt	5.txt	68.txt	76.txt
# 11.jpg	1.jpg	28.jpg	36.jpg	44.jpg	52.jpg	60.jpg	69.jpg	77.jpg
# 11.txt	1.txt	28.txt	36.txt	44.txt	52.txt	60.txt	69.txt	77.txt
# 12.jpg	20.jpg	29.jpg	37.jpg	45.jpg	53.jpg	61.jpg	6.jpg	78.jpg
# 12.txt	20.txt	29.txt	37.txt	45.txt	53.txt	61.txt	6.txt	78.txt
# 13.jpg	21.jpg	2.jpg	38.jpg	46.jpg	54.jpg	62.jpg	70.jpg	79.jpg
# 13.txt	21.txt	2.txt	38.txt	46.txt	54.txt	62.txt	70.txt	79.txt
# 14.jpg	22.jpg	30.jpg	39.jpg	47.jpg	55.jpg	63.jpg	71.jpg	7.jpg
# 14.txt	22.txt	30.txt	39.txt	47.txt	55.txt	63.txt	71.txt	7.txt
# 15.jpg	23.jpg	31.jpg	3.jpg	48.jpg	56.jpg	64.jpg	72.jpg	80.jpg
# 15.txt	23.txt	31.txt	3.txt	48.txt	56.txt	64.txt	72.txt	80.txt
# 16.jpg	24.jpg	32.jpg	40.jpg	49.jpg	57.jpg	65.jpg	73.jpg	8.jpg
# 16.txt	24.txt	32.txt	40.txt	49.txt	57.txt	65.txt	73.txt	8.txt
# 17.jpg	25.jpg	33.jpg	41.jpg	4.jpg	58.jpg	66.jpg	74.jpg	9.jpg
# ...

# %% [markdown]
# ## Listing of Label's "Coordinates"

# %%
import glob
import os
import re

txt_file_paths = glob.glob(r"data/obj/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)
# Out:
# 0 0.535156 0.468384 0.820312 0.622951
#
# ['0', '0.535156', '0.468384', '0.820312', '0.622951']
# 0 data/obj/10.txt
# 0 0.535156 0.468384 0.820312 0.622951
# 0 0.643750 0.576112 0.640625 0.655738
#
# ['0', '0.643750', '0.576112', '0.640625', '0.655738']
# 1 data/obj/11.txt
# 0 0.643750 0.576112 0.640625 0.655738
# 0 0.585156 0.500000 0.754687 0.887324
#
# ['0', '0.585156', '0.500000', '0.754687', '0.887324']
# 2 data/obj/12.txt
# 0 0.585156 0.500000 0.754687 0.887324
# 0 0.645312 0.510638 0.687500 0.893617
#
# ['0', '0.645312', '0.510638', '0.687500', '0.893617']
# 3 data/obj/13.txt
# 0 0.645312 0.510638 0.687500 0.893617
# 0 0.293750 0.386968 0.506250 0.731383
#
# ['0', '0.293750', '0.386968', '0.506250', '0.731383']
# 3 data/obj/13.txt
# 0 0.293750 0.386968 0.506250 0.731383
# 0 0.482812 0.462441 0.431250 0.483568
#
# ['0', '0.482812', '0.462441', '0.431250', '0.483568']
# 4 data/obj/14.txt
# 0 0.482812 0.462441 0.431250 0.483568
# 0 0.550781 0.653396 0.582812 0.533958
#
# ...

# %% [markdown]
# ## Printing Image Names

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
print(images_list)
# Out:
# ['data/obj/10.jpg', 'data/obj/11.jpg', 'data/obj/12.jpg', 'data/obj/13.jpg', 'data/obj/14.jpg', 'data/obj/15.jpg', 'data/obj/16.jpg', 'data/obj/17.jpg', 'data/obj/18.jpg', 'data/obj/19.jpg', 'data/obj/1.jpg', 'data/obj/20.jpg', 'data/obj/21.jpg', 'data/obj/22.jpg', 'data/obj/23.jpg', 'data/obj/24.jpg', 'data/obj/25.jpg', 'data/obj/26.jpg', 'data/obj/27.jpg', 'data/obj/28.jpg', 'data/obj/29.jpg', 'data/obj/2.jpg', 'data/obj/30.jpg', 'data/obj/31.jpg', 'data/obj/32.jpg', 'data/obj/33.jpg', 'data/obj/34.jpg', 'data/obj/35.jpg', 'data/obj/36.jpg', 'data/obj/37.jpg', 'data/obj/38.jpg', 'data/obj/39.jpg', 'data/obj/3.jpg', 'data/obj/40.jpg', 'data/obj/41.jpg', 'data/obj/42.jpg', 'data/obj/43.jpg', 'data/obj/44.jpg', 'data/obj/45.jpg', 'data/obj/46.jpg', 'data/obj/47.jpg', 'data/obj/48.jpg', 'data/obj/49.jpg', 'data/obj/4.jpg', 'data/obj/50.jpg', 'data/obj/51.jpg', 'data/obj/52.jpg', 'data/obj/53.jpg', 'data/obj/54.jpg', 'data/obj/55.jpg', 'data/obj/56.jpg', 'data/obj/57.jpg', 'data/obj/58.
# ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %% [markdown]
# ## The Final Showdown: Training Begins

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.517628, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 3053.104492, iou_loss = 0.000000, total_loss = 3053.104492
#  total_bbox = 1793, rewritten_bbox = 1.226994 %
#
#  26: 1295.520752, 1329.945801 avg loss, 0.000000 rate, 6.307840 seconds, 1664 images, 9.332925 hours left
# Loaded: 0.000062 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.421857, GIOU: 0.375278), Class: 0.405879, Obj: 0.421717, No Obj: 0.481103, .5R: 0.200000, .75R: 0.000000, count: 5, class_loss = 170.760437, iou_loss = 1.367783, total_loss = 172.128220
# ...

# %%
! mv "/content/gdrive/My Drive/Weapon-Recognition/darknet/yolov3_training_last.weights" "/content/gdrive/My Drive/yolov3/"

# %%
! ls "/content/gdrive/My Drive/yolov3/"
# Out:
# images	yolov3_training_last.weights

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# '01 - Migraine.mp3'		   Images_Downloader44.jpg
# 'Class 10 Chemistry Notes'	   Images_Downloader45.jpg
#  Classroom			   Images_Downloader46.jpg
# 'Colab Notebooks'		   Images_Downloader47.jpg
#  darknet			   Images_Downloader48.jpg
# 'EPFEK prefinal copy draft.docx'   Images_Downloader49.jpg
# 'Getting started.pdf'		   Images_Downloader4.jpg
#  Handgun-SemiAutomaticPistol	   Images_Downloader50.jpg
#  Images_Downloader		   Images_Downloader51.jpg
#  Images_Downloader10.jpg	   Images_Downloader52.jpg
#  Images_Downloader11.jpg	   Images_Downloader53.jpg
#  Images_Downloader12.jpg	   Images_Downloader54.jpg
#  Images_Downloader13.jpg	   Images_Downloader55.jpg
#  Images_Downloader14.jpg	   Images_Downloader56.jpg
#  Images_Downloader15.jpg	   Images_Downloader57.jpg
#  Images_Downloader16.jpg	   Images_Downloader58.jpg
#  Images_Downloader17.jpg	   Images_Downloader59.jpg
#  Images_Downloader18.jpg	   Images_Downloader5.jpg
#  Images_Downloader19.jpg	   Images_Downloader60.jpg
# ...

# %% [markdown]
# ## The execution below worked.

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000004, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000001, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 93661, rewritten_bbox = 1.016432 %
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.905748, GIOU: 0.903855), Class: 0.999713, Obj: 0.883592, No Obj: 0.004039, .5R: 1.000000, .75R: 1.000000, count: 4, class_loss = 0.053692, iou_loss = 0.042375, total_loss = 0.096067
# ...
